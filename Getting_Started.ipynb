# %% [markdown]
# ## **Getting Started with Matplotlib**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('student_depression_dataset.csv') ## Data Gathering

# %%
df.sample(5)
# Out:
#            id  Gender   Age       City Profession  Academic Pressure  \
# 9052    45624  Female  28.0       Agra    Student                3.0
# 26799  135232  Female  23.0      Patna    Student                5.0
# 9561    48224    Male  26.0  Faridabad    Student                3.0
# 12509   63267  Female  30.0     Jaipur    Student                4.0
# 5975    30062  Female  33.0     Meerut    Student                3.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 9052             0.0  8.03                 1.0               0.0
# 26799            0.0  5.99                 3.0               0.0
# 9561             0.0  8.24                 4.0               0.0
# 12509            0.0  8.49                 1.0               0.0
# 5975             0.0  9.71                 4.0               0.0
#
#           Sleep Duration Dietary Habits   Degree  \
# 9052           7-8 hours       Moderate   B.Tech
# 26799          7-8 hours      Unhealthy  B.Pharm
# ...

# %%
df.shape
# Out:
# (27901, 18)

# %% [markdown]
# ### Data Exploration while Plotting Graphs ---> Dataset ---> Which Categorical Column or Numerical Column

# %% [markdown]
# ### **Categorical Columns**
#
# #### Categorical Column ---> A column that contains values divided into different **categories or groups**.
#
# #### Example ---> 10 Students ---> 10 Mobile Phones ---> Different Mobile Brands ---> **Categories**
#
# ### **Categories**
#
# #### **1. Apple**
# #### **2. Nokia**
# #### **3. Samsung**
#
# ### **Numerical Columns**
#
# #### Numerical Column ---> A column that contains **numbers or numerical values** which can be used for mathematical calculations.
#
# #### Example ---> 100 Students ---> Their **Marks** ---> Numerical Data
#
# ### **Numerical Values**
#
# #### **1. 85**
# #### **2. 90**
# #### **3. 72**
# #### **4. 65**
# #### **5. 95**

# %%
df.columns
# Out:
# Index(['id', 'Gender', 'Age', 'City', 'Profession', 'Academic Pressure',
#        'Work Pressure', 'CGPA', 'Study Satisfaction', 'Job Satisfaction',
#        'Sleep Duration', 'Dietary Habits', 'Degree',
#        'Have you ever had suicidal thoughts ?', 'Work/Study Hours',
#        'Financial Stress', 'Family History of Mental Illness', 'Depression'],
#       dtype='str')

# %%
## categorical Column ---> Gender, City, Profession, Sleep Duration, Dietary Habits, Degree, Family History of Mental Illness
## Numerical Column ---> id, Age, CGPA, etc

# %% [markdown]
# ### **Univariate Analysis & Bivariate Analysis**
#
# #### **Univariate Analysis** ---> It is the analysis of **only one variable or one column at a time (Unique Column)** to understand its values, distribution, or patterns.
#
# #### **Example** ---> Analyzing only the **Marks** column of 10 students.
#
# #### **Bivariate Analysis** ---> It is the analysis of **two variables or two columns at a time** to understand the relationship between them.
#
# #### **Example** ---> Analyzing the relationship between **Marks** and **Study Hours**.
# #### Bivariate Analysis ---> 1. Numeric-Numeric 2. Numeric-Categorical 3. Categorical-Categorical
#
# ### **Multivariate Analysis**
#
# #### **Multivariate Analysis** ---> It is the analysis of **three or more variables or columns at the same time** to understand the relationship and patterns between them.
#
# #### **Example** ---> Analyzing **Study Hours, Marks, and Attendance** together to understand how they affect a student's performance.

# %% [markdown]
# ### 2D PLOT
# #### Specific Purpose ---> Specific Plot
#
# #### 2D Plot ---> usually work with 2 columns ---> Categorical-Numeric
# #### X axis ---> Categorical column Data or Category
# #### Y axis ---> Vaue that is going to change or that varies for the category
#
# #### 2D Line Plot or in general Line Plot, it can be used for Time Series Data
# #### Time Series data ---> Stock Price on Month basis
# #### Time Series data is the data that varies with Time  or it can be the data where the values varies continouslly (Phone Brand ---> Price)
# #### Tracking Weight over the Months (Time Series Data)

# %% [markdown]
# #### Dataset ---> Indian Actors Fees for a Movie ----> Actors name ---> Categorical ---> X Axis
# #### Price ---> Numerical---> Y axis

# %%
x=['Sunjay Dutt', 'Sharukh Khan', 'Salman Khan', 'Amir Khan', 'Akshay Kumar']
y=[20000000, 70000000, 50000000, 110000000, 40000000]

## Create a Line Plot ---> plt.plot(x,y) --> Create the Graph for us
plt.plot(x,y)

# %%
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#       Sleep Duration Dietary Habits   Degree  \
# 0          5-6 hours        Healthy  B.Pharm
# 1          5-6 hours       Moderate      BSc
# 2  Less than 5 hours        Healthy       BA
# ...

# %%
data=df['Gender'].value_counts().plot(kind='line')

# %%
data=df['Gender'].value_counts()

# %%
x=data.index
y=data.values

# %%
plt.plot(x,y)

# %% [markdown]
# ### **plt.figure()** ---> It is used to **create a new figure or canvas** where we can plot our graph.
# #### **Syntax** ---> `plt.figure()`
# #### **Example** ---> `plt.figure(figsize=(10,5))`
# ----
# ### **plt.title()** ---> It is used to **add a title to the graph**.
# #### parameter ---> color ---> what color the Title is going to have
# #### **Syntax** ---> `plt.title("Title of Graph")`
#
# #### **Example** ---> `plt.title("Student Marks")`
# ----
# ### **plt.ylabel()** ---> It is used to **add a label to the Y-axis** of the graph.
# #### **Syntax** ---> `plt.ylabel("Y-axis Label")`
#
# #### **Example** ---> `plt.ylabel("Marks")`
# ----
# ### **plt.xlabel()** ---> It is used to **add a label to the X-axis** of the graph.
#
# #### **Syntax** ---> `plt.xlabel("X-axis Label")`
#
# #### **Example** ---> `plt.xlabel("Student Name")`
# ----
# ### **plt.grid()** ---> It is used to **show grid lines** on the graph, which makes it easier to read the values.
#
# #### **Syntax** ---> `plt.grid()`
#
# #### **Example** ---> `plt.grid(True)`
# ----
# ### **plt.show()** ---> helps in represent the chart
#
# #### **Syntax** ---> `plt.show()`
#
# #### **Example** ---> `plt.show()`
# ----
# ### **plt.xlim()** ---> It is used to **set the limits of the X-axis** of the graph.
#
# #### **Syntax** ---> `plt.xlim(min_value, max_value)`
#
# #### **Example** ---> `plt.xlim(0, 100)` ---> `plt.xlim(10, 1000)`
#
#
# ### **plt.ylim()** ---> It is used to **set the limits of the Y-axis** of the graph.
#
# #### **Syntax** ---> `plt.ylim(min_value, max_value)`
#
# #### **Example** ---> `plt.ylim(0, 500)`

# %%
plt.figure(figsize=(10,6))
plt.title("Count of Population as Gender", color='red')
plt.ylabel("Count of Population")
plt.xlabel("Gender")
# plt.plot(x,y, color="red")
plt.plot(x,y, color="#09dc45", marker='*', linestyle='--',linewidth=3, markersize=9, label='Gender Population')
plt.grid()
plt.show()

# %% [markdown]
# ### Customization For Line
#
# #### Parameter:
# #### 1. color ---> What is going to be color of the Line ---> for eg. red, green, blue OR HTML hash code
#
# #### 2. marker ---> how point of intersection appears --> o , ^ , s , + , * , d , h , p
#
# #### 3. linestyle ---> it will be defining the style of the line ---> '--' , '-., '-' , ':'
#
# #### 4. linewidth ----> it shows the width of the line ---> 1,1.5,2,....
#
# #### 5. markersize ---> it shows the markersize or it can change the size of the marker, default --> 6, ---> 10, 9,...
#
# #### 6. label ---> label that what this specific line is representing but is only help while plotting multiple line in a single visualozation

# %%
df.sample(5)
# Out:
#            id  Gender   Age       City Profession  Academic Pressure  \
# 16462   83297    Male  21.0     Jaipur    Student                4.0
# 6361    31868    Male  32.0  Hyderabad    Student                4.0
# 22857  115249    Male  33.0   Srinagar    Student                4.0
# 16298   82485    Male  24.0   Vadodara    Student                5.0
# 20859  105506  Female  29.0      Thane    Student                3.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 16462            0.0  6.08                 5.0               0.0
# 6361             0.0  5.45                 3.0               0.0
# 22857            0.0  9.39                 4.0               0.0
# 16298            0.0  5.82                 4.0               0.0
# 20859            0.0  9.56                 2.0               0.0
#
#           Sleep Duration Dietary Habits  Degree  \
# 16462          5-6 hours      Unhealthy  M.Tech
# 6361           7-8 hours      Unhealthy    B.Ed
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  str
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  str
#  4   Profession                             27901 non-null  str
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
#  10  Sleep Duration                         27901 non-null  str
# ...

# %%
df['Age']=df['Age'].astype('int32')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  str
#  2   Age                                    27901 non-null  int32
#  3   City                                   27901 non-null  str
#  4   Profession                             27901 non-null  str
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
#  10  Sleep Duration                         27901 non-null  str
# ...

# %%
df['CGPA']=df['CGPA'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  str
#  2   Age                                    27901 non-null  int32
#  3   City                                   27901 non-null  str
#  4   Profession                             27901 non-null  str
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float32
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
#  10  Sleep Duration                         27901 non-null  str
# ...

# %%
df['Gender']=df['Gender'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  category
#  2   Age                                    27901 non-null  int32
#  3   City                                   27901 non-null  str
#  4   Profession                             27901 non-null  str
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float32
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
#  10  Sleep Duration                         27901 non-null  str
# ...

# %%
df['City']=df['City'].astype('category')

# %%
df['Profession']=df['Profession'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  category
#  2   Age                                    27901 non-null  int32
#  3   City                                   27901 non-null  category
#  4   Profession                             27901 non-null  category
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float32
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
# ...

# %%
df['Sleep Duration']=df['Sleep Duration'].astype('category')

# %%
df['Dietary Habits']=df['Dietary Habits'].astype('category')

# %%
df['Degree']=df['Degree'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  category
#  2   Age                                    27901 non-null  int32
#  3   City                                   27901 non-null  category
#  4   Profession                             27901 non-null  category
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float32
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
# ...

# %% [markdown]
# ### **groupby()**
#
# #### **groupby()** ---> It helps to **group the rows based on the values of a particular column**. After creating groups, we can apply mathematical functions like `sum()`, `mean()`, `max()`, `min()`, etc. on the grouped data.
#
# #### **Example**
#
# #### Dataset ---> Country and Sales Information
#
# | Country | Sales |
# |---|---:|
# | India | 150 |
# | China | 5000 |
# | USA | 1000 |
# | India | 5000 |
# | USA | 5000 |
#
# #### **Country-wise Total Sales**
#
# ##### **Group 1** ---> `India` ---> `150 + 5000 = 5150`
#
# ##### **Group 2** ---> `China` ---> `5000`
#
# ##### **Group 3** ---> `USA` ---> `1000 + 5000 = 6000`
#
# #### **Syntax** ---> `df.groupby("column_name")["value_column"].sum()`
# #### **Syntax** ---> `df.groupby("categorical_col")["Numerical column"].mathematical_fun()`
#
# ### **Example** ---> `df.groupby("Country")["Sales"].sum()`

# %%
## Line Plot ---> AGE vs CGPA

df['Age'].value_counts().head(10)
# Out:
# Age
# 24    2258
# 20    2237
# 28    2133
# 29    1950
# 33    1893
# 25    1784
# 21    1726
# 23    1645
# 18    1587
# 19    1560
# Name: count, dtype: int64

# %%
data = df.groupby('Age')['CGPA'].mean().head(10)

# %%
x=data.index
y=data.values

# %%
plt.figure(figsize=(10,5))
plt.title('CGPA Distribution As per Age')
plt.xlabel('AGE')
plt.ylabel('CGPA')
plt.plot(x,y, color='red', linestyle='--', linewidth=1.5,marker='o',markersize='7')
plt.grid()
plt.show()

# %%
df.sample(5)
# Out:
#           id  Gender  Age         City Profession  Academic Pressure  \
# 16093  81379  Female   32     Ludhiana    Student                3.0
# 5910   29689  Female   31      Chennai    Student                1.0
# 2527   12928    Male   18       Mumbai    Student                3.0
# 8159   41087  Female   32     Varanasi    Student                3.0
# 178      852    Male   29  Vasai-Virar    Student                3.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 16093            0.0   5.0                 1.0               0.0
# 5910             0.0   8.0                 4.0               0.0
# 2527             0.0   8.0                 5.0               0.0
# 8159             0.0   8.0                 3.0               0.0
# 178              0.0   8.0                 2.0               0.0
#
#           Sleep Duration Dietary Habits    Degree  \
# 16093  More than 8 hours       Moderate        MD
# 5910           5-6 hours        Healthy       LLB
# ...

# %%
df['Financial Stress'].value_counts()
# Out:
# Financial Stress
# 5.0    6715
# 4.0    5775
# 3.0    5226
# 1.0    5121
# 2.0    5061
# Name: count, dtype: int64

# %%
df.groupby('City')['Financial Stress'].mean()
# Out:
# City
# 3.0                   5.000000
# Agra                  3.095978
# Ahmedabad             3.253417
# Bangalore             3.173403
# Bhavna                3.000000
# Bhopal                3.094218
# Chennai               3.152542
# City                  2.000000
# Delhi                 3.204427
# Faridabad             3.034707
# Gaurav                5.000000
# Ghaziabad             3.052349
# Harsh                 5.000000
# Harsha                2.000000
# Hyderabad             3.269604
# Indore                3.172628
# Jaipur                3.216216
# Kalyan                3.133758
# Kanpur                2.965517
# Khaziabad             5.000000
# Kibara                1.000000
# Kolkata               3.117371
# Less Delhi            1.000000
# Less than 5 Kalyan    1.000000
# Lucknow               3.069264
# Ludhiana              3.192619
# M.Com                 5.000000
# M.Tech                1.000000
# ME                    1.000000
# Meerut                3.030303
# ...

# %% [markdown]
# ### Top 10 Populated City provide the Mean Financial Stress Value

# %%
x=df['City'].value_counts().head(10)

# %%
x
# Out:
# City
# Kalyan         1570
# Srinagar       1372
# Hyderabad      1340
# Vasai-Virar    1290
# Lucknow        1155
# Thane          1139
# Ludhiana       1111
# Agra           1094
# Surat          1078
# Kolkata        1066
# Name: count, dtype: int64

# %%
y=df.groupby('City')['Financial Stress'].mean()

# %%
y=y[(y.index== 'Kalyan') | (y.index== 'Srinagar') | (y.index== 'Hyderabad') | (y.index== 'Vasai-Virar') | (y.index== 'Lucknow') | (y.index== 'Thane') | (y.index== 'Ludhiana') | (y.index== 'Agra') | (y.index== 'Surat') | (y.index== 'Kolkata')]

# %%
y
# Out:
# City
# Agra           3.095978
# Hyderabad      3.269604
# Kalyan         3.133758
# Kolkata        3.117371
# Lucknow        3.069264
# Ludhiana       3.192619
# Srinagar       3.115889
# Surat          3.166976
# Thane          3.107112
# Vasai-Virar    3.135659
# Name: Financial Stress, dtype: float64

# %%
x=x.sort_index()

# %%
x
# Out:
# City
# Agra           1094
# Hyderabad      1340
# Kalyan         1570
# Kolkata        1066
# Lucknow        1155
# Ludhiana       1111
# Srinagar       1372
# Surat          1078
# Thane          1139
# Vasai-Virar    1290
# Name: count, dtype: int64

# %%
y
# Out:
# City
# Agra           3.095978
# Hyderabad      3.269604
# Kalyan         3.133758
# Kolkata        3.117371
# Lucknow        3.069264
# Ludhiana       3.192619
# Srinagar       3.115889
# Surat          3.166976
# Thane          3.107112
# Vasai-Virar    3.135659
# Name: Financial Stress, dtype: float64

# %%
x=x.index

# %%
x
# Out:
# CategoricalIndex(['Agra', 'Hyderabad', 'Kalyan', 'Kolkata', 'Lucknow',
#                   'Ludhiana', 'Srinagar', 'Surat', 'Thane', 'Vasai-Virar'],
#                  categories=['3.0', 'Agra', 'Ahmedabad', 'Bangalore', ..., 'Vadodara', 'Varanasi', 'Vasai-Virar', 'Visakhapatnam'], ordered=False, dtype='category', name='City')

# %%
y=y.values

# %%
y
# Out:
# array([3.09597806, 3.26960418, 3.13375796, 3.11737089, 3.06926407,
#        3.19261926, 3.11588921, 3.16697588, 3.1071115 , 3.13565891])

# %%
plt.figure(figsize=(10,5))
plt.title('top 10 Cities Mean Financial Stress')
plt.xlabel('City')
plt.ylabel('Mean Financial Stress')
plt.plot(x,y,color='blue', linestyle='--', linewidth=1.8,marker='o',markersize='7')
plt.grid()
plt.show()

# %%
sales=pd.read_csv('Chocolate Sales.csv')

# %%
sales.head()
# Out:
#      Sales Person    Country              Product        Date      Amount  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco  04/01/2022   $5,320.00
# 1     Van Tuxwell      India        85% Dark Bars  01/08/2022   $7,896.00
# 2    Gigi Bohling      India  Peanut Butter Cubes  07/07/2022   $4,501.00
# 3    Jan Morforth  Australia  Peanut Butter Cubes  27/04/2022  $12,726.00
# 4  Jehu Rudeforth         UK  Peanut Butter Cubes  24/02/2022  $13,685.00
#
#    Boxes Shipped
# 0            180
# 1             94
# 2             91
# 3            342
# 4            184

# %%
sales.shape
# Out:
# (1093, 6)

# %%
sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1093 entries, 0 to 1092
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales Person   1093 non-null   str
#  1   Country        1093 non-null   str
#  2   Product        1093 non-null   str
#  3   Date           1093 non-null   str
#  4   Amount         1093 non-null   str
#  5   Boxes Shipped  1093 non-null   int64
# dtypes: int64(1), str(5)
# memory usage: 51.4 KB

# %%
sales['Sales Person']=sales['Sales Person'].astype('category')

# %%
sales['Country']=sales['Country'].astype('category')

# %%
sales['Product']=sales['Product'].astype('category')

# %%
# sales['Date']=pd.to_datetime(sales['Date'])
sales['Date'] = pd.to_datetime(sales['Date'], errors='coerce')
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_28676\2803558638.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   sales['Date'] = pd.to_datetime(sales['Date'], errors='coerce')

# %%
sales['Date'] = sales['Date'].dt.month_name()

# %%
sales['Date']
# Out:
# 0         April
# 1       January
# 2          July
# 3           NaN
# 4           NaN
#          ...
# 1088        NaN
# 1089        NaN
# 1090       July
# 1091        NaN
# 1092        NaN
# Name: Date, Length: 1093, dtype: str

# %%
### To covert a date column to datetime you can use pd.to_datetime()
### To extract a Year from DateTime column ---> df['col_name'].dt.year
### To extract a Month value(1-12) from DateTime column ---> df['col_name'].dt.month
### To extract a Month name from DateTime column ---> df['col_name'].dt.month_name

# %%
sales['Amount'].value_counts()
# Out:
# Amount
# $2,317.00    5
# $4,361.00    4
# $3,472.00    4
# $6,454.00    4
# $7,714.00    4
#             ..
# $8,337.00    1
# $8,134.00    1
# $8,491.00    1
# $3,066.00    1
# $4,410.00    1
# Name: count, Length: 827, dtype: int64

# %%
sales['Amount']=sales['Amount'].str.strip("$")

# %%
sales['Amount']
# Out:
# 0        5,320.00
# 1        7,896.00
# 2        4,501.00
# 3       12,726.00
# 4       13,685.00
#           ...
# 1088       301.00
# 1089     4,410.00
# 1090     6,559.00
# 1091       574.00
# 1092     2,086.00
# Name: Amount, Length: 1093, dtype: str

# %%
sales['Amount']=sales['Amount'].str.replace(",","")

# %%
sales['Amount']
# Out:
# 0        5320.00
# 1        7896.00
# 2        4501.00
# 3       12726.00
# 4       13685.00
#           ...
# 1088      301.00
# 1089     4410.00
# 1090     6559.00
# 1091      574.00
# 1092     2086.00
# Name: Amount, Length: 1093, dtype: str

# %%
sales['Amount'] = sales['Amount'].astype(float).astype('int32')

# %%
sales['Boxes Shipped']=sales['Boxes Shipped'].astype('int32')

# %%
sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1093 entries, 0 to 1092
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales Person   1093 non-null   category
#  1   Country        1093 non-null   category
#  2   Product        1093 non-null   category
#  3   Date           430 non-null    str
#  4   Amount         1093 non-null   int32
#  5   Boxes Shipped  1093 non-null   int32
# dtypes: category(3), int32(2), str(1)
# memory usage: 20.8 KB

# %%
sales['Date']=sales['Date'].astype('category')

# %%
sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1093 entries, 0 to 1092
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales Person   1093 non-null   category
#  1   Country        1093 non-null   category
#  2   Product        1093 non-null   category
#  3   Date           430 non-null    category
#  4   Amount         1093 non-null   int32
#  5   Boxes Shipped  1093 non-null   int32
# dtypes: category(4), int32(2)
# memory usage: 13.4 KB

# %%
data=sales.groupby('Date')['Amount'].sum()

# %%
data
# Out:
# Date
# April        312487
# August       173250
# December     194796
# February     146097
# January      168728
# July         271747
# June         113470
# March        192059
# May          216132
# November     280252
# October      185479
# September    144291
# Name: Amount, dtype: int32

# %%
data.index=pd.CategoricalIndex(data.index, categories=['January', 'February', 'March', 'April', 'May', 'June', 'July','August', 'September', 'October', 'November', 'December'])

# %%
data=data.sort_index()

# %%
data
# Out:
# Date
# January      168728
# February     146097
# March        192059
# April        312487
# May          216132
# June         113470
# July         271747
# August       173250
# September    144291
# October      185479
# November     280252
# December     194796
# Name: Amount, dtype: int32

# %%
x=data.index

# %%
y=data.values

# %%
y
# Out:
# array([168728, 146097, 192059, 312487, 216132, 113470, 271747, 173250,
#        144291, 185479, 280252, 194796], dtype=int32)

# %%
plt.figure(figsize=(10,5))
plt.title('Monthly Sales')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.plot(x,y,color='green', linestyle='--', linewidth=1.5,marker='o',markersize='7')
plt.grid()
plt.show()

# %% [markdown]
# ### **Types of Plots**
#
# #### **1. Line Plot** ---> It is mainly used for **Time Series Analysis** to understand how a value is changing over a period of time.
#
# #### **2. Scatter Plot** ---> It is mainly used for **Bivariate Analysis**, where we work with **two numerical columns**.
#
# #### Scatter Plot ---> It helps us understand how a change in **one numerical variable** is related to a change in **another numerical variable**.
#
# #### **Example** --->
# #### x ---> Age ---> 10, 15, 20, 25, 30, ...., 75
# #### y ---> Cholesterol Level ---> 50, 60, 75, 80, 65, ...., 80
#
# #### Scatter Plot ---> It helps us check whether, with an **increase in Age**, the Cholesterol Level is:
# #### 1. Increasing
# #### 2. Decreasing
# #### 3. Staying almost steady
#
# #### **Scatter Plot** ---> It helps us understand the **correlation or relationship between two numerical variables**.

# %%
df
# Out:
#            id  Gender  Age           City Profession  Academic Pressure  \
# 0           2    Male   33  Visakhapatnam    Student                5.0
# 1           8  Female   24      Bangalore    Student                2.0
# 2          26    Male   31       Srinagar    Student                3.0
# 3          30  Female   28       Varanasi    Student                3.0
# 4          32  Female   25         Jaipur    Student                4.0
# ...       ...     ...  ...            ...        ...                ...
# 27896  140685  Female   27          Surat    Student                5.0
# 27897  140686    Male   27       Ludhiana    Student                2.0
# 27898  140689    Male   31      Faridabad    Student                3.0
# 27899  140690  Female   18       Ludhiana    Student                5.0
# 27900  140699    Male   27          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
df.head()
# Out:
#    id  Gender  Age           City Profession  Academic Pressure  \
# 0   2    Male   33  Visakhapatnam    Student                5.0
# 1   8  Female   24      Bangalore    Student                2.0
# 2  26    Male   31       Srinagar    Student                3.0
# 3  30  Female   28       Varanasi    Student                3.0
# 4  32  Female   25         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0   8.0                 2.0               0.0
# 1            0.0   5.0                 5.0               0.0
# 2            0.0   7.0                 5.0               0.0
# 3            0.0   5.0                 2.0               0.0
# 4            0.0   8.0                 3.0               0.0
#
#       Sleep Duration Dietary Habits   Degree  \
# 0          5-6 hours        Healthy  B.Pharm
# 1          5-6 hours       Moderate      BSc
# 2  Less than 5 hours        Healthy       BA
# ...

# %%
df['Age'].value_counts()
# Out:
# Age
# 24    2258
# 20    2237
# 28    2133
# 29    1950
# 33    1893
# 25    1784
# 21    1726
# 23    1645
# 18    1587
# 19    1560
# 34    1468
# 27    1462
# 31    1427
# 32    1262
# 22    1160
# 26    1155
# 30    1145
# 35      10
# 38       8
# 36       7
# 42       4
# 39       3
# 48       3
# 43       2
# 46       2
# 37       2
# 58       1
# 49       1
# 51       1
# 44       1
# 59       1
# 54       1
# 56       1
# 41       1
# Name: count, dtype: int64

# %%
### Age vs Average CGPA

# %%
data=df.groupby('Age')['CGPA'].mean().head(10)

# %%
x=data.index

# %%
y=data.values

# %%
### Function to create a Scatter Plot ---> plt.scatter(x,y)
plt.figure(figsize=(10,4))
plt.title('Average CGPA Variation as per AGE')
plt.xlabel('Age')
plt.ylabel('Average CGPA')
plt.scatter(x,y, color='red',marker='*')
plt.grid()
plt.show()

# %%
import numpy as np
x=np.linspace(-10,10,50)
y=10+x+3 + np.random.randint(0,300,50)

# %%
plt.figure(figsize=(10,4))
plt.title('Total CGPA Variation as per AGE')
plt.xlabel('A')
plt.ylabel('Average CGPA')
plt.scatter(x,y, color='red',marker='*')
plt.grid()
plt.show()

# %%
sales.sample(5)
# Out:
#          Sales Person      Country              Product Date  Amount  \
# 827       Brien Boise        India  Spicy Special Slims  NaN    1302
# 553       Brien Boise  New Zealand           White Choc  NaN    5509
# 22     Marney O'Breen          USA          After Nines  NaN    4753
# 509       Kaine Padly    Australia     Fruit & Nut Bars  NaN    7434
# 974  Karlen McCaffrey    Australia      Raspberry Choco  NaN     994
#
#      Boxes Shipped
# 827             33
# 553            321
# 22             163
# 509             85
# 974             57

# %%
x=sales['Boxes Shipped']
y=sales['Amount']

# %%
plt.figure(figsize=(10,4))
plt.title('Total Amount Variation as per Total Boxes Shipped')
plt.xlabel('Boxes Shipped')
plt.ylabel('Amount')
plt.scatter(x,y, color='yellow',marker='o')
plt.grid()
plt.show()

# %%
### If there is any way in which we can create a scatter plot from line plot only

#### Line Plot ---> Special Case of Scatter Plot as soon as we will join the points of scatter plot we will get the line plot

# %%
data=df.groupby('Age')['CGPA'].mean().head(10)
x=data.index
y=data.values

# %%
plt.scatter(x,y)

# %%
plt.plot(x,y,marker='o')

# %%
### If you want to come up with a Scatter Plot From a Line Plot

# %%
plt.plot(x,y,'o') # use 'o'

# %%
### Large Dataset ---> Lakhs or Crores Crores of Rows ---> plot('o')---> Scatter plot---> Faster
### Small Dataset ---> Hundreads or Thousands of Pows ---> scatter() ---> Scatter pot ---> Faster

# %% [markdown]
# #### Line Chart ---> Line chart was being used for representing Time Series Analysis
#
# #### Scatter Plot ---> Scatter Plot is used to represnt the corelation in between Two Numerical Columns (Such that How on changes in the first numerical column it affects the variable in the second Numerical Column)
#
# #### Bar Plot ---> Bar Plot is being used for Categorical - Numerical Columns
# ### Data----> Sales in Multiple Countries ---> group the row on the basis of country Name & will come up with the Total Sum of Sales
# #### 1000 records ---> 80 records ---> India ---> group all 80 rows or records ---> Sales value associated with these 80 rows ---> Aggregation Operation (sum(), count(), mean())
#
# #### Categorical Column ----> Numerical Column Aggregation
# #### groupby ---> is something we will using Everytime
# #### Univariate & Bivariate Both Analysis will be done in Bar Plot
# #### Univariate ---> Categorical Column Data Distribution (how the data in Multiple Categories is Distributed)
# #### Use case ---> Aggregate Analysis of Groups

# %%
df.sample(5)
# Out:
#           id  Gender  Age         City Profession  Academic Pressure  \
# 4388   22020  Female   27     Varanasi    Student                5.0
# 11072  56048  Female   27  Vasai-Virar    Student                4.0
# 19332  97928    Male   26       Meerut    Student                2.0
# 487     2490    Male   28       Bhopal    Student                5.0
# 8810   44449  Female   25  Vasai-Virar    Student                1.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 4388             0.0   9.0                 1.0               0.0
# 11072            0.0   9.0                 2.0               0.0
# 19332            0.0   9.0                 4.0               0.0
# 487              0.0   8.0                 5.0               0.0
# 8810             0.0   5.0                 3.0               0.0
#
#           Sleep Duration Dietary Habits  Degree  \
# 4388           5-6 hours        Healthy     PhD
# 11072  Less than 5 hours        Healthy  B.Tech
# ...

# %%
data=df['Gender'].value_counts()

# %%
data
# Out:
# Gender
# Male      15547
# Female    12354
# Name: count, dtype: int64

# %%
x=data.index
y=data.values

# %%
### plotting Bar plot ---> bar() ---> plt.bar(x,y,color)
plt.figure(figsize=(8,4))
plt.title('Univariate Analysis on Gender Column')
plt.bar(x,y)
plt.show()

# %%
df.head()
# Out:
#    id  Gender  Age           City Profession  Academic Pressure  \
# 0   2    Male   33  Visakhapatnam    Student                5.0
# 1   8  Female   24      Bangalore    Student                2.0
# 2  26    Male   31       Srinagar    Student                3.0
# 3  30  Female   28       Varanasi    Student                3.0
# 4  32  Female   25         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0   8.0                 2.0               0.0
# 1            0.0   5.0                 5.0               0.0
# 2            0.0   7.0                 5.0               0.0
# 3            0.0   5.0                 2.0               0.0
# 4            0.0   8.0                 3.0               0.0
#
#       Sleep Duration Dietary Habits   Degree  \
# 0          5-6 hours        Healthy  B.Pharm
# 1          5-6 hours       Moderate      BSc
# 2  Less than 5 hours        Healthy       BA
# ...

# %%
### Dietary Habits vs Depression
df['Dietary Habits'].value_counts()
# Out:
# Dietary Habits
# Unhealthy    10317
# Moderate      9921
# Healthy       7651
# Others          12
# Name: count, dtype: int64

# %%
data=df[(df['Dietary Habits'] == 'Unhealthy') | (df['Dietary Habits'] == 'Moderate') | (df['Dietary Habits'] =='Healthy')]

# %%
data['Dietary Habits'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Dietary Habits'>

# %%
### remove_unused_categories()

# %%
data['Dietary Habits']=data['Dietary Habits'].cat.remove_unused_categories()

# %%
data['Dietary Habits'].value_counts()
# Out:
# Dietary Habits
# Unhealthy    10317
# Moderate      9921
# Healthy       7651
# Name: count, dtype: int64

# %%
d=data.groupby('Dietary Habits')['Depression'].sum()

# %%
d
# Out:
# Dietary Habits
# Healthy      3473
# Moderate     5558
# Unhealthy    7297
# Name: Depression, dtype: int64

# %%
x=d.index
y=d.values

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 3 artists>

# %%
### Gender ----> Equal Distribution vs Academic Pressure

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Male      15539
# Female    12350
# Name: count, dtype: int64

# %%
Male=data[data['Gender']=='Male']

# %%
Female=data[data['Gender']=='Female']

# %%
Male.head()
# Out:
#    id Gender  Age           City Profession  Academic Pressure  Work Pressure  \
# 0   2   Male   33  Visakhapatnam    Student                5.0            0.0
# 2  26   Male   31       Srinagar    Student                3.0            0.0
# 5  33   Male   29           Pune    Student                2.0            0.0
# 6  52   Male   30          Thane    Student                3.0            0.0
# 8  59   Male   28         Nagpur    Student                3.0            0.0
#
#    CGPA  Study Satisfaction  Job Satisfaction     Sleep Duration  \
# 0   8.0                 2.0               0.0          5-6 hours
# 2   7.0                 5.0               0.0  Less than 5 hours
# 5   5.0                 3.0               0.0  Less than 5 hours
# 6   9.0                 4.0               0.0          7-8 hours
# 8   9.0                 1.0               0.0          7-8 hours
#
#   Dietary Habits   Degree Have you ever had suicidal thoughts ?  \
# ...

# %%
Female.head()
# Out:
#      id  Gender  Age       City Profession  Academic Pressure  Work Pressure  \
# 1     8  Female   24  Bangalore    Student                2.0            0.0
# 3    30  Female   28   Varanasi    Student                3.0            0.0
# 4    32  Female   25     Jaipur    Student                4.0            0.0
# 7    56  Female   30    Chennai    Student                2.0            0.0
# 13  100  Female   19     Rajkot    Student                2.0            0.0
#
#     CGPA  Study Satisfaction  Job Satisfaction     Sleep Duration  \
# 1    5.0                 5.0               0.0          5-6 hours
# 3    5.0                 2.0               0.0          7-8 hours
# 4    8.0                 3.0               0.0          5-6 hours
# 7    8.0                 4.0               0.0  Less than 5 hours
# 13   8.0                 4.0               0.0  Less than 5 hours
#
#    Dietary Habits    Degree Have you ever had suicidal thoughts ?  \
# ...

# %%
### concat() ---> concat() function joins dataset or Multiple dataset by using concat()
#### pd.concat([df_1,df_2,df_3,.....])

# %%
df=pd.concat([Male, Female])

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      15539
# Female    12350
# Name: count, dtype: int64

# %%
data=df.groupby('Gender')['Academic Pressure'].sum()

# %%
data
# Out:
# Gender
# Female    39219.0
# Male      48387.0
# Name: Academic Pressure, dtype: float64

# %%
x=data.index
y=data.values

# %%
plt.figure(figsize=(5,4))
plt.title('Gender Based Academic Pressure')
plt.xlabel('Gender')
plt.ylabel('Total Academic Pressure')
plt.bar(x,y,color='green',width=0.4)
plt.show()

# %%
sales
# Out:
#           Sales Person    Country              Product     Date  Amount  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco    April    5320
# 1          Van Tuxwell      India        85% Dark Bars  January    7896
# 2         Gigi Bohling      India  Peanut Butter Cubes     July    4501
# 3         Jan Morforth  Australia  Peanut Butter Cubes      NaN   12726
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes      NaN   13685
# ...                ...        ...                  ...      ...     ...
# 1088       Brien Boise  Australia  Peanut Butter Cubes      NaN     301
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims      NaN    4410
# 1090    Jehu Rudeforth        USA           White Choc     July    6559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup      NaN     574
# 1092    Dotty Strutley      India              Eclairs      NaN    2086
#
#       Boxes Shipped
# 0               180
# 1                94
# 2                91
# ...

# %%
### Country Based Total Sales

# %%
data=sales.groupby('Country')['Amount'].sum()

# %%
data
# Out:
# Country
# Australia      1137367
# Canada          962899
# India          1040725
# New Zealand     950418
# UK             1051792
# USA            1035349
# Name: Amount, dtype: int32

# %%
x=data.index
y=data.values

# %%
plt.figure(figsize=(7,4))
plt.title('Country Based Total Sales')
plt.xlabel('Country')
plt.ylabel('Amount')
plt.bar(x,y,color='green',width=0.8)
plt.show()

# %%
sales['Product'].value_counts().head(7)
# Out:
# Product
# 50% Dark Bites         60
# Eclairs                60
# Smooth Sliky Salty     59
# White Choc             58
# Drinking Coco          56
# Spicy Special Slims    54
# Organic Choco Syrup    52
# Name: count, dtype: int64

# %%
data = sales[(sales['Product'] == '50 % Dark Bites') | (sales['Product'] == 'Eclairs') | (sales['Product'] == 'Smooth Sliky Salty') | (sales['Product'] == 'White Choc') | (sales['Product'] == 'Drinking Coco') | (sales['Product'] == 'Spicy Special Slims') | (sales['Product'] == 'Organic Choco Syrup')]

# %%
data['Product'].value_counts()
# Out:
# Product
# Eclairs                 60
# Smooth Sliky Salty      59
# White Choc              58
# Drinking Coco           56
# Spicy Special Slims     54
# Organic Choco Syrup     52
# 50% Dark Bites           0
# 70% Dark Bites           0
# 85% Dark Bars            0
# 99% Dark & Pure          0
# After Nines              0
# Almond Choco             0
# Baker's Choco Chips      0
# Caramel Stuffed Bars     0
# Choco Coated Almonds     0
# Fruit & Nut Bars         0
# Manuka Honey Choco       0
# Milk Bars                0
# Mint Chip Choco          0
# Orange Choco             0
# Peanut Butter Cubes      0
# Raspberry Choco          0
# Name: count, dtype: int64

# %%
data['Product']=data['Product'].cat.remove_unused_categories()

# %%
data['Product'].value_counts()
# Out:
# Product
# Eclairs                60
# Smooth Sliky Salty     59
# White Choc             58
# Drinking Coco          56
# Spicy Special Slims    54
# Organic Choco Syrup    52
# Name: count, dtype: int64

# %%
d=data.groupby('Product')['Boxes Shipped'].sum()

# %%
x=d.index
y=d.values

# %%
plt.figure(figsize=(10,4))
plt.title('Product Boxes Shipped')
plt.xlabel('Product')
plt.ylabel('Total Boxes')
plt.bar(x,y,color='green',width=0.8)
plt.show()

# %% [markdown]
# ### **`Horizontal Bar Chart ---> Bars are going to be Horizontal`**
# ### barh() ---> Horizontal Bar Chart

# %%
plt.figure(figsize=(10,4))
plt.title('Product Boxes Shipped')
plt.ylabel('Product')
plt.xlabel('Total Boxes shipped')
plt.barh(x,y,color='purple',height=0.8)
plt.show()
